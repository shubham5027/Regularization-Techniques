# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score

# %%
df=pd.read_csv('titanic_toy.csv')

# %%
df
# Out:
#       Age     Fare  Family  Survived
# 0    22.0   7.2500       1         0
# 1    38.0  71.2833       1         1
# 2    26.0   7.9250       0         1
# 3    35.0  53.1000       1         1
# 4    35.0   8.0500       0         0
# ..    ...      ...     ...       ...
# 886  27.0  13.0000       0         0
# 887  19.0  30.0000       0         1
# 888   NaN  23.4500       3         0
# 889  26.0      NaN       0         1
# 890  32.0   7.7500       0         0
#
# [891 rows x 4 columns]

# %%
df.head()
# Out:
#     Age     Fare  Family  Survived
# 0  22.0   7.2500       1         0
# 1  38.0  71.2833       1         1
# 2  26.0   7.9250       0         1
# 3  35.0  53.1000       1         1
# 4  35.0   8.0500       0         0

# %%
df.isnull().sum()
# Out:
# Age         177
# Fare         45
# Family        0
# Survived      0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
Si=SimpleImputer(strategy='mean')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       714 non-null    float64
#  1   Fare      846 non-null    float64
#  2   Family    891 non-null    int64
#  3   Survived  891 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 28.0 KB

# %%
df.describe()
# Out:
#               Age        Fare      Family    Survived
# count  714.000000  846.000000  891.000000  891.000000
# mean    29.699118   32.279338    0.904602    0.383838
# std     14.526497   50.305796    1.613459    0.486592
# min      0.420000    0.000000    0.000000    0.000000
# 25%     20.125000    7.895800    0.000000    0.000000
# 50%     28.000000   14.454200    0.000000    0.000000
# 75%     38.000000   31.206250    1.000000    1.000000
# max     80.000000  512.329200   10.000000    1.000000

# %%
X=df.drop(['Survived'],axis=1)

# %%
Y=df['Survived']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,random_state=0,test_size=0.2)

# %%
X_train_new=Si.fit_transform(X_train)
X_test_new=Si.transform(X_test)

# %%
lr=LinearRegression()
rd=Ridge(solver='sparse_cg',alpha=0.1)
ls=Lasso()

# %%
rd.fit(X_train_new,y_train)  #ridge regressiin9
# Out:
# Ridge(alpha=0.1, solver='sparse_cg')

# %%
lr.fit(X_train_new,y_train) #Linear Regression
# Out:
# LinearRegression()

# %%
ls.fit(X_train_new,y_train) #Lasso regession
# Out:
# Lasso()

# %%
y_pred_1=lr.predict(X_test_new)
y_pred_2=rd.predict(X_test_new)
y_pred_3=ls.predict(X_test_new)

# %%
r1=r2_score(y_test,y_pred_1)
r2=r2_score(y_test,y_pred_2)
r3=r2_score(y_test,y_pred_3)

print("linear Regression",r1)
print("ridge regression",r2)
print("Lasss regression",r3)
# Out:
# linear Regression 0.10461641897424523
# ridge regression 0.10461649933620887
# Lasss regression 0.099823497581089
